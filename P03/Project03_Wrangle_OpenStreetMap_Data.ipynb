# %% [markdown]
# # Wrangle OpenStreetMap Data

# %% [markdown]
# ## Code from Data Wrangling with MongoDB - Lesson 6

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import codecs
import json
from pprint import pprint

# %% [markdown]
# ## Count tags
#
# The following routine counts the tags for each

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_type_portuguese_re = re.compile(r'^\b\S+\.?', re.IGNORECASE)

def audit_street_type(street_types, street_name, expected):
    m = street_type_portuguese_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile, expected):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'], expected)

    return street_types


def update_name(name, mapping):
    m = street_type_portuguese_re.search(name)
    if m:
        street_type = m.group()
        updated_street_type = mapping.get(street_type)
        if updated_street_type:
            name = name.replace(street_type, updated_street_type)
    return name

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        # YOUR CODE HERE
        node['type'] = element.tag
        node.update(element.attrib)
        latitude = node.pop('lat', None)
        longitude = node.pop('lon', None)
        if latitude and longitude:
            node['pos'] = [float(latitude), float(longitude)]
        node['created'] = {}
        for created_attr in CREATED:
            created_attr_value = node.pop(created_attr, None )
            if created_attr_value:
                node['created'][created_attr] = created_attr_value
        
        for tag in  element.iter('tag'):
            k = tag.attrib['k']
            if problemchars.findall(k):
                pass
            elif k[:5] == 'addr:':
                address_key = k[5:]
                if lower_colon.findall(address_key):
                    pass
                else:
                    if 'address' not in node.keys():
                        node['address'] = {}
                    value = tag.attrib.get('v')
                    if address_key =='street':
                        value = update_name(value, mapping)
                    node['address'][address_key] = value
            else:
                node[k] = tag.attrib.get('v')
        node_refs = [tag.get('ref') for tag in element.iter('nd')]
        if node_refs:
            node['node_refs'] = node_refs
        
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
                print "printed "
    return data

# %% [markdown]
# ## Overview of the Data
#
# In this project I have used the metro area of Porto, Portugal. If you want to run this code, please download the OSM XML data from [Map Zen](https://mapzen.com/data/metro-extracts) and extract it in the directory of this Notebook.
#
# The direct link is the following:
# https://s3.amazonaws.com/metro-extracts.mapzen.com/porto_portugal.osm.bz2

# %%
path = 'porto_portugal.osm'

# %% [markdown]
# #### Size of the file

# %%
import os
print "Dataset size is %.1fMB"%(os.path.getsize(path)/1000000.)
# Out:
# Dataset size is 150.6MB

# %% [markdown]
# #### Number of unique users
#
# The following users were found in our data:

# %%
def get_user(element):
    return element.attrib.get('user')

users = set()
for _, element in ET.iterparse(path):
    user = get_user(element)
    if user:
        users.add(user)

# %%
print "----------------------"
print "    First 20 users"
print "----------------------"
for u in list(users)[:20]:
    print u
print '...'
print "----------------------"
print "Total number of unique users: %d"%len(users)
# Out:
# ----------------------
#     First 20 users
# ----------------------
# Paulo Salvador
# RuiPinto_12
# fribeiro
# nscerqueira
# jfig
# Marco Vergueira
# paulamir
# alvieboy
# elsevilla
# OSMF Redaction Account
# PortugalMaps
# Bruno Loureiro
# Ropino
# AndrewBuck
# xybot
# meldias
# Ruca x16
# Lobinho
# djpatricio
# Ana Pereira
# ...
# ----------------------
# Total number of unique users: 895

# %% [markdown]
# #### Number of different tags (including nodes and ways)

# %% [markdown]
# The following function is used to count all the tags that appear in our XML document.

# %%
def count_tags(filename):
        # YOUR CODE HERE
        tree = ET.parse(filename)
        root = tree.getroot()

        tags_count = {root.tag: 1}
        for child in root.findall('.//'):
            tag = child.tag
            tags_count[tag] = tags_count.get(tag, 0) + 1
        return tags_count

# %%
tags = count_tags(path)
# %store tags
# Out:
# Stored 'tags' (dict)

# %% [markdown]
# The following tags and respective count can be found in our data:

# %%
pprint(tags)
# Out:
# {'bounds': 1,
#  'member': 11831,
#  'nd': 885620,
#  'node': 677414,
#  'osm': 1,
#  'relation': 1146,
#  'tag': 293128,
#  'way': 103625}

# %% [markdown]
# ## Problems encountered in the map

# %% [markdown]
# The first thing a noticed in the data is that street names are written in Portuguese, which means that the conventional parsing techniques for English streets does not apply.
# In Portuguese the following guidelines may help to define the first version of parser for street addresses:
#
# - Street types appear in the first word of the address
# - Street types are commonly Rua, Avenida, Estrada, among others.
#
# Using the method _audit_ I will try to find out other Portuguese street types.
# This method basically collects all the street addresses that are not recognized by the parser, grouping them per inferred street type. It infers the street type by extracting the first word of the address.

# %%
audit(path)
# Out:
# defaultdict(set,
#             {'25': {'25 Abril'},
#              'Alameda': {u'Alameda Bas\xedlio Teles',
#               'Alameda Futebol Clube de Infesta',
#               u'Alameda de S\xe3o Silvestre'},
#              u'Av': {u'Av Lu\xeds de Cam\xf5es'},
#              'Av.': {'Av. 24',
#               u'Av. Men\xe9res',
#               'Av. Pedra Verde',
#               'Av. Principal',
#               'Av. da Pedra Verde'},
#              'Brito': {'Brito Capelo'},
#              'Cais': {'Cais das Lavandeiras'},
#              'Calcada': {'Calcada da Feira dos Dez'},
#              u'Cal\xe7ada': {u'Cal\xe7ada da Cabine',
#               u'Cal\xe7ada da Junqueira',
#               u'Cal\xe7ada da Serra',
#               u'Cal\xe7ada de Fontela',
#               u'Cal\xe7ada de Valinhos',
#               u'Cal\xe7ada do Arco'},
#              'Caminho': {'Caminho de Vilar'},
#              u'Campo': {u'Campo dos M\xe1rtires da P\xe1tria'},
#              'Ciclovia': {'Ciclovia da Foz'},
#              u'Costa': {u'Costa Padr\xe3o'},
#              'EN': {'EN 204/5'},
#              'Esplanada': {'Esplanada do Rio de Janeiro'},
#              'Ladeira': {'Ladeira da Quinta Nova'},
#              u'Largo': {u'Largo 1\xba de Dezembro',
#               'Largo 25 de Abril',
#               'Largo Padre Baltazar Guedes',
#               u'Largo Padre Lu\xeds Gonzaga Queir\xf3s',
#               u'Largo Padre Sa\xfade',
#               u'Largo da Esta\xe7\xe3o',
#               'Largo da Feira dos Dez',
#               u'Largo de Santo Ant\xf3nio',
#               u'Largo de S\xe3o Bento',
#               u'Largo de S\xe3o Domingos',
#               u'Largo dos L\xf3ios'},
#              'Lugar': {'Lugar da Igreja'},
#              'Medas': {'Medas'},
#              'Mercado': {'Mercado Ferreira Borges'},
#              'Nacional': {'Nacional 1', 'Nacional 1/IC2'},
#              'Nossa': {'Nossa Senhora do Amparo'},
#              'Padre': {'Padre Ricardo Neto'},
#              'Paramos': {'Paramos'},
#              'Praceta': {'Praceta 5 de Outubro',
#               u'Praceta Jaime Cortes\xe3o',
#               u'Praceta Manuel Gon\xe7alves Ramos',
#               'Praceta Parque Nascente',
#               'Praceta Professor Egas Moniz',
#               u'Praceta Z\xe9 Telhado',
#               'Praceta da Ranha',
#               'Praceta de Macau',
#               u'Praceta de Manuel Gon\xe7alves Lage'},
#              u'Pra\xe7a': {u'Pra\xe7a 5 de Outubro',
#               u'Pra\xe7a Cid. Salvador',
#               u'Pra\xe7a Coronel Pacheco',
#               u'Pra\xe7a Dom Afonso V',
#               u'Pra\xe7a Dom Jo\xe3o I',
#               u'Pra\xe7a Dona Filipa de Lencastre',
#               u'Pra\xe7a General Humberto Delgado',
#               u'Pra\xe7a Marqu\xeas de Pombal',
#               u'Pra\xe7a Mouzinho de Albuquerque',
#               u'Pra\xe7a Vasco da Gama',
#               u'Pra\xe7a da Batalha',
#               u'Pra\xe7a da Liberdade',
#               u'Pra\xe7a da Rep\xfablica',
#               u'Pra\xe7a da Ribeira',
#               u'Pra\xe7a de Carlos Alberto',
#               u'Pra\xe7a do Almada',
#               u'Pra\xe7a do Ex\xe9rcito Libertador',
#               u'Pra\xe7a dos Poveiros'},
#              u'Pra\xe7eta': {u'Pra\xe7eta Professor Sampaio'},
#              u'P\xe1tio': {u'P\xe1tio das Escadas do Monte dos Judeus'},
#              u'R': {u'R Escola Preparat\xf3ria'},
#              'R.': {'R. Adelino Amaro da Costa', 'R. Silva Brinco'},
#              'R.S.Pedro': {'R.S.Pedro de Formariz'},
#              'RUA': {'RUA CONDE FERREIRA',
#               'RUA Central de Gens',
#               'RUA DRAGOES SANDINENSES'},
#              'Travessa': {'Travessa Alto de Curres',
#               'Travessa Alto do Fojo',
#               u'Travessa Dona S\xedlvia Alves Teixeira',
#               u'Travessa Jos\xe9 Fontana',
#               'Travessa Justiniano Pacheco',
#               'Travessa Professor Manuel Borges de Azevedo',
#               'Travessa da Asoreia',
#               'Travessa da Bela Vista',
#               'Travessa da Cabine',
#               'Travessa da Encosta da Sobreira',
#               'Travessa da Escola',
#               u'Travessa da Esta\xe7\xe3o',
#               'Travessa da Fonte',
#               'Travessa da Ponte',
#               'Travessa da Portela',
#               'Travessa da Serra',
#               'Travessa das Pinguelas',
#               'Travessa de Aguim',
#               'Travessa de Cimo de Vila',
#               'Travessa de Nova Sintra',
#               u'Travessa de S\xe3o Domingos',
#               'Travessa do Arco',
#               'Travessa do Carregal',
#               'Travessa do Carvalhal',
#               'Travessa do Cruzeiro',
#               'Travessa do Fojo',
#               'Travessa do Pinhal',
#               'Travessa do Tanque',
#               'Travessa dos Outeirinhos'},
#              u'Urbaniza\xe7\xe3o': {u'Urbaniza\xe7\xe3o Industrial da Carri\xe7a',
#               u'Urbaniza\xe7\xe3o Industrial do Soeiro'},
#              'Via': {'Via Futebol Clube do Porto', u'Via Panor\xe2mica'},
#              'Viela': {'Viela da Portela',
#               'Viela do Pocinho',
#               'Viela dos Congregados'},
#              u'Zona': {'Zona Industrial Maia I Sector X - Lote 384',
#               u'Zona Industrial da Carri\xe7a, lote 19/20'},
#              'da': {'da fonte'},
#              'do': {'do Sol'}})

# %% [markdown]
# We can see that there were many street types that were not being included.
# Let's add it.

# %%
expected = ["Rua", "Avenida", "Estrada", "Travessa", "Viela", "Zona", "Praceta", "Praça", "Calçada", "Largo", "Lugar", "Campo", "Ciclovia", "Caminho", "Via"]
audit(path, expected)
# Out:
# /Users/cruz/dev/udacity/venv/lib/python2.7/site-packages/ipykernel/__main__.py:33: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
# defaultdict(set,
#             {'25': {'25 Abril'},
#              'Alameda': {u'Alameda Bas\xedlio Teles',
#               'Alameda Futebol Clube de Infesta',
#               u'Alameda de S\xe3o Silvestre'},
#              u'Av': {u'Av Lu\xeds de Cam\xf5es'},
#              'Av.': {'Av. 24',
#               u'Av. Men\xe9res',
#               'Av. Pedra Verde',
#               'Av. Principal',
#               'Av. da Pedra Verde'},
#              'Brito': {'Brito Capelo'},
#              'Cais': {'Cais das Lavandeiras'},
#              'Calcada': {'Calcada da Feira dos Dez'},
#              u'Cal\xe7ada': {u'Cal\xe7ada da Cabine',
#               u'Cal\xe7ada da Junqueira',
#               u'Cal\xe7ada da Serra',
#               u'Cal\xe7ada de Fontela',
#               u'Cal\xe7ada de Valinhos',
#               u'Cal\xe7ada do Arco'},
#              u'Costa': {u'Costa Padr\xe3o'},
#              'EN': {'EN 204/5'},
#              'Esplanada': {'Esplanada do Rio de Janeiro'},
#              'Ladeira': {'Ladeira da Quinta Nova'},
#              'Medas': {'Medas'},
#              'Mercado': {'Mercado Ferreira Borges'},
#              'Nacional': {'Nacional 1', 'Nacional 1/IC2'},
#              'Nossa': {'Nossa Senhora do Amparo'},
#              'Padre': {'Padre Ricardo Neto'},
#              'Paramos': {'Paramos'},
#              u'Pra\xe7a': {u'Pra\xe7a 5 de Outubro',
#               u'Pra\xe7a Cid. Salvador',
#               u'Pra\xe7a Coronel Pacheco',
#               u'Pra\xe7a Dom Afonso V',
#               u'Pra\xe7a Dom Jo\xe3o I',
#               u'Pra\xe7a Dona Filipa de Lencastre',
#               u'Pra\xe7a General Humberto Delgado',
#               u'Pra\xe7a Marqu\xeas de Pombal',
#               u'Pra\xe7a Mouzinho de Albuquerque',
#               u'Pra\xe7a Vasco da Gama',
#               u'Pra\xe7a da Batalha',
#               u'Pra\xe7a da Liberdade',
#               u'Pra\xe7a da Rep\xfablica',
#               u'Pra\xe7a da Ribeira',
#               u'Pra\xe7a de Carlos Alberto',
#               u'Pra\xe7a do Almada',
#               u'Pra\xe7a do Ex\xe9rcito Libertador',
#               u'Pra\xe7a dos Poveiros'},
#              u'Pra\xe7eta': {u'Pra\xe7eta Professor Sampaio'},
#              u'P\xe1tio': {u'P\xe1tio das Escadas do Monte dos Judeus'},
#              u'R': {u'R Escola Preparat\xf3ria'},
#              'R.': {'R. Adelino Amaro da Costa', 'R. Silva Brinco'},
#              'R.S.Pedro': {'R.S.Pedro de Formariz'},
#              'RUA': {'RUA CONDE FERREIRA',
#               'RUA Central de Gens',
#               'RUA DRAGOES SANDINENSES'},
#              u'Urbaniza\xe7\xe3o': {u'Urbaniza\xe7\xe3o Industrial da Carri\xe7a',
#               u'Urbaniza\xe7\xe3o Industrial do Soeiro'},
#              'da': {'da fonte'},
#              'do': {'do Sol'}})

# %% [markdown]
# Another issue is that some street types are written using abreviations. E.g., Sometimes _Avenida_ appears as _Av._.
# The method _update_name_ is going to be used to update these

# %%
mapping = {
    "R": "Rua",
    "R.": "Rua",
    "Praca": "Praça",
    "Av.": "Avenida",
    "Calcada": "Calçada"
}
name = 'R. da Liberdade'
print '%s => %s'%(name, update_name(name, mapping))
# Out:
# R. da Liberdade => Rua da Liberdade

# %% [markdown]
# Portuguese has some latin characters that can be a trouble, such as ç in Praça.
# Instead, we read Pra\xe7a, which does not make sense.
# Although these weird characters might make sense with different encoding, we will also convert them to something Python can recognize.
#
# Let's do this by updating *update_name* method and _mapping_ dictionary.

# %%
def update_name(name, mapping):
    m = street_type_portuguese_re.search(name)
    if m:
        street_type = m.group()
        updated_street_type = mapping.get(street_type)
        if updated_street_type:
            name = name.encode('utf-8').replace(street_type.encode('utf-8'), updated_street_type)
    return name

# %%
mapping = {
    "R": "Rua",
    "R.": "Rua",
    "Praca": "Praça",
    "Av.": "Avenida",
    "Calcada": "Calçada",
    u'Urbaniza\xe7\xe3o': 'Urbanização',
    u'Pra\xe7a': 'Praça',
}
name = u'Pra\xe7a da Liberdade'
updated_name = update_name(name, mapping)
print '%s => %s'%(name.encode('utf-8'), updated_name)
# Out:
# Praça da Liberdade => Praça da Liberdade

# %% [markdown]
# # City Names
#
# Sometimes the name of cities can also be an issue. Some users may use acronyms, others might suppress some propositions when present in the name.
#
# Let's make an audit for this. I'll start with counting the number of distinct cities.

# %%
def count_cities(filename):
        # YOUR CODE HERE
        tree = ET.parse(filename)
        root = tree.getroot()

        cities_count = {}
        for child in root.findall('.//tag'):
            if child.attrib['k'] == 'addr:city':
                city = child.attrib['v'].lower()
                cities_count[city] = cities_count.get(city, 0) + 1
        return cities_count

# %%
cities = count_cities(path)

# %% [markdown]
# ### Distinct citiy names

# %%
len(cities)
# Out:
# 77

# %% [markdown]
# We have 77 different city names.
# According to Wikipedia (https://en.wikipedia.org/wiki/Metropolitan_Area_of_Porto#Population), Porto metropolitan area has only 17 cities:
#
# - Santo Tirso
# - Trofa
# - Arouca
# - Oliveira de Azeméis
# - Santa Maria da Feira
# - São João da Madeira
# - Vale de Cambra
# - Espinho
# - Gondomar
# - Maia
# - Matosinhos
# - Porto
# - Póvoa de Varzim
# - Valongo
# - Vila do Conde
# - Vila Nova de Gaia
# - Paredes

# %%
pprint(cities)
# Out:
# {'alfena': 3,
#  'arcozelo, vila nova de gaia': 1,
#  'argoncilhe': 7,
#  'baguim do monte': 1,
#  'baltar': 2,
#  'bonfim': 1,
#  'branzelo': 1,
#  u'calend\xe1rio': 74,
#  u'campanh\xe3': 1,
#  'canelas': 1,
#  'canelas vng': 1,
#  'canidelo': 1,
#  'canidelo - v. n. gaia': 1,
#  'canidelo - vila nova de gaia': 1,
#  u'cast\xealo da maia': 1,
#  u'cust\xf3ias': 5,
#  u'cust\xf3ias mts': 1,
#  'ermesinde': 6,
#  u'esmeriz -vila nova de famalic\xe3o': 1,
#  'espinho': 7,
#  'fajozes': 3,
#  u'fi\xe3es': 10,
#  'gandra': 2,
#  'gens': 1,
#  'gondomar': 4,
#  u'gondomar (s\xe3o cosme)': 9,
#  u'grij\xf3': 8,
#  u'guid\xf5es': 1,
#  'lagares': 2,
#  'lagoa': 3,
#  'lamelas': 8,
#  u'le\xe7a da palmeira': 4,
#  u'le\xe7a do balio': 3,
#  'lisboa': 3,
#  u'lob\xe3o': 1,
#  'lourosa': 24,
#  'lousado': 1,
#  'macieira da maia': 2,
#  'madalena': 1,
#  'mafamude': 1,
#  'maia': 847,
#  'matosinhos': 8,
#  u'milheir\xf3s': 3,
#  'mindelo': 2,
#  'modelos': 1,
#  'moreira da maia': 3,
#  u'mosteir\xf3': 7,
#  'nogueira da regedoura': 10,
#  'paranhos': 1,
#  'paredes': 1,
#  u'pa\xe7os de ferreira': 7,
#  u'pa\xe7os de ferriera': 1,
#  u'pedrou\xe7os': 1,
#  'penafiel': 1,
#  'porto': 242,
#  'povoa de varzim': 1,
#  u'p\xf3voa de varzim': 1,
#  'ramalde': 6,
#  'ribeiros altos - paredes': 1,
#  u'ribeir\xe3o': 6,
#  'rio tinto': 5,
#  'roriz': 1,
#  's. martinho do campo': 1,
#  's.pedro de formariz': 1,
#  'sandim': 1,
#  'santo tirso': 13,
#  'senhora da hora': 2,
#  u's\xe3o  mamede de infesta': 13,
#  u's\xe3o felix da mariha': 1,
#  u's\xe3o mamede de infesta': 2,
#  'trofa': 1,
#  'valadares': 1,
#  'valongo': 7,
#  'vila do conde': 9,
#  u'vila nova de famalic\xe3o': 5,
#  'vila nova de gaia': 17,
#  u'\xe1guas santas': 4}

# %% [markdown]
# From the list above we can explain this large number of cities by the fact that many users have given the name of civil parish.
#
# Sometimes both the civil parish and the city are written (e.g., 'canidelo - vila nova de gaia' where _Vila Nova de Gaia_ is the city) and other times only the parish is given (e.g., canidelo).
#
# In addition, cities with long names also appear written with acronyms. E.g., _Vila Nova de Gaia_ appears once as _V. N. Gaia_.

# %% [markdown]
# #### Solving the issue automatically

# %%
parish_city_mapping = {
    'canidelo' : 'vila nova de gaia',
    'canelas' : 'vila nova de gaia',
    'mafamude': 'vila nova de gaia',
    'baltar': 'paredes',
    'ermesinde': 'valongo',
    u'cust\xf3ias': 'matosinhos',
    u'cast\xealo da maia': 'matosinhos',
    u'le\xe7a da palmeira': 'matosinhos',
    'mindelo': 'vila do conde',
    'bonfim': 'porto',
    'paranhos': 'porto',
    'ramalde': 'porto',
    u'campanh\xe3':'porto',
    'senhora da hora': 'matosinhos',
    'valadares': 'vila nova de gaia',
    u'\xe1guas santas': 'maia',
    'lousado': u'vila nova de famalic\xe3o',
    u'cast\xealo da maia': 'matosinhos',
    u'le\xe7a da palmeira': 'matosinhos',
    'alfena': 'valongo',
    'roriz': 'santo tirso',
    'baguim do monte': 'gondomar',
    'fajozes': 'vila do conde',
}

city_names = [
    'vila nova de gaia',
    'santo tirso',
    'trofa',
    'arouca',
    'oliveira de azeméis',
    'santa maria da feira',
    'são joão da madeira',
    'vale de cambra',
    'espinho',
    'gondomar',
    'maia',
    'matosinhos',
    'porto',
    'póvoa de varzim',
    'valongo',
    'vila do conde',
    'vila nova de gaia',
    'paredes',

]

# %%
def update_city_name(name, mapping, city_names):
    name = name.lower().encode('utf-8')
    updated_name = mapping.get(name)
    if updated_name:
        return updated_name
    if name not in city_names:
        for city in city_names:
            if city in name:
                return city
    return name.decode('utf-8')

# %%
updated_cities = {}
for (city, count) in cities.iteritems():
    updated_city = update_city_name(city, parish_city_mapping, city_names)
    updated_cities[updated_city] = (updated_cities.get(updated_city) or 0) + count
print len(updated_cities)
pprint(updated_cities)
# Out:
# 58
# {u'argoncilhe': 7,
#  u'baguim do monte': 1,
#  u'bonfim': 1,
#  u'branzelo': 1,
#  u'calend\xe1rio': 74,
#  u'campanh\xe3': 1,
#  u'canelas vng': 1,
#  u'canidelo - v. n. gaia': 1,
#  u'cust\xf3ias': 5,
#  u'cust\xf3ias mts': 1,
#  u'esmeriz -vila nova de famalic\xe3o': 1,
#  u'espinho': 7,
#  u'fajozes': 3,
#  u'fi\xe3es': 10,
#  u'gandra': 2,
#  u'gens': 1,
#  'gondomar': 13,
#  u'grij\xf3': 8,
#  u'guid\xf5es': 1,
#  u'lagares': 2,
#  u'lagoa': 3,
#  u'lamelas': 8,
#  u'le\xe7a da palmeira': 4,
#  u'le\xe7a do balio': 3,
#  u'lisboa': 3,
#  u'lob\xe3o': 1,
#  u'lourosa': 24,
#  u'madalena': 1,
#  'maia': 853,
#  'matosinhos': 10,
#  u'milheir\xf3s': 3,
#  u'modelos': 1,
#  u'mosteir\xf3': 7,
#  u'nogueira da regedoura': 10,
#  'paredes': 4,
#  u'pa\xe7os de ferreira': 7,
#  u'pa\xe7os de ferriera': 1,
#  u'pedrou\xe7os': 1,
#  u'penafiel': 1,
#  'porto': 243,
#  u'povoa de varzim': 1,
#  u'p\xf3voa de varzim': 1,
#  u'ramalde': 6,
#  u'ribeir\xe3o': 6,
#  u'rio tinto': 5,
#  u's. martinho do campo': 1,
#  u's.pedro de formariz': 1,
#  u'sandim': 1,
#  u'santo tirso': 14,
#  u's\xe3o  mamede de infesta': 13,
#  u's\xe3o felix da mariha': 1,
#  u's\xe3o mamede de infesta': 2,
#  u'trofa': 1,
#  'valongo': 16,
#  'vila do conde': 11,
#  u'vila nova de famalic\xe3o': 6,
#  'vila nova de gaia': 23,
#  u'\xe1guas santas': 4}

# %% [markdown]
# ## Other ideas about the datasets

# %% [markdown]
# One thing that could be interesting would be getting a ranking of the most active contributors in the data.
# This could be achieved by making a few changes in the method that retrieves unique users. The collections.Counter class would help in the implementation (see https://docs.python.org/dev/library/collections.html#collections.Counter).
#
#
# If this dataset was frequently, another that could be done would be getting the areas that have been recently updated -- in the last day/week/month.
#
# This could be done by filtering nodes using the attribute **timestamp** and according to the intended time window.

# %% [markdown]
# ## Convert data to json
#
# The following method *process_map* processes data with the transformations described above and stores data into a json file with the name "porto_portugal.osm.json".

# %%
json_data = process_map("porto_portugal.osm")
# Out:
# [{'created': {'changeset': '12009377',
#    'timestamp': '2012-06-25T10:15:29Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '5'},
#   'id': '24960108',
#   'pos': [41.23288, -8.6772787],
#   'type': 'node'},
#  {'created': {'changeset': '12017708',
#    'timestamp': '2012-06-25T23:55:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '2'},
#   'id': '24960109',
#   'pos': [41.2628808, -8.6851482],
#   'type': 'node'},
#  {'created': {'changeset': '10218263',
#    'timestamp': '2011-12-27T18:09:16Z',
#    'uid': '291378',
#    'user': 'Micael Dias',
#    'version': '5'},
#   'id': '25440124',
#   'pos': [41.1443339, -8.5873853],
#   'type': 'node'},
#  {'created': {'changeset': '8956209',
#    'timestamp': '2011-08-08T11:43:29Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25440125',
#   'pos': [41.1446759, -8.5868845],
#   'type': 'node'},
#  {'created': {'changeset': '8956209',
#    'timestamp': '2011-08-08T11:43:29Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25440126',
#   'pos': [41.1454585, -8.5861672],
#   'type': 'node'},
#  {'created': {'changeset': '31550798',
#    'timestamp': '2015-05-28T23:55:28Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '7'},
#   'id': '25440127',
#   'pos': [41.1460212, -8.5858367],
#   'railway': 'switch',
#   'type': 'node'},
#  {'created': {'changeset': '10778488',
#    'timestamp': '2012-02-24T16:17:57Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '6'},
#   'id': '25447543',
#   'pos': [41.0049544, -8.6443314],
#   'type': 'node'},
#  {'created': {'changeset': '10778488',
#    'timestamp': '2012-02-24T16:17:57Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '5'},
#   'id': '25447544',
#   'pos': [41.0038956, -8.6442833],
#   'type': 'node'},
#  {'created': {'changeset': '10778488',
#    'timestamp': '2012-02-24T16:17:57Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '6'},
#   'id': '25447545',
#   'pos': [41.0031045, -8.6441448],
#   'type': 'node'},
#  {'created': {'changeset': '10778488',
#    'timestamp': '2012-02-24T16:17:57Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25447546',
#   'pos': [40.9980048, -8.6428351],
#   'type': 'node'},
#  {'created': {'changeset': '10774394',
#    'timestamp': '2012-02-24T02:07:01Z',
#    'uid': '291378',
#    'user': 'Micael Dias',
#    'version': '3'},
#   'id': '25447547',
#   'pos': [40.9927403, -8.6413397],
#   'type': 'node'},
#  {'created': {'changeset': '10778488',
#    'timestamp': '2012-02-24T16:17:57Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25447548',
#   'pos': [40.9878291, -8.6400552],
#   'type': 'node'},
#  {'created': {'changeset': '10778488',
#    'timestamp': '2012-02-24T16:17:57Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25447549',
#   'pos': [40.9820304, -8.6385385],
#   'type': 'node'},
#  {'created': {'changeset': '8956209',
#    'timestamp': '2011-08-08T11:43:30Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25449245',
#   'pos': [41.1471851, -8.5853787],
#   'type': 'node'},
#  {'created': {'changeset': '8956209',
#    'timestamp': '2011-08-08T11:43:30Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25449246',
#   'pos': [41.1477198, -8.585217],
#   'type': 'node'},
#  {'created': {'changeset': '8956209',
#    'timestamp': '2011-08-08T11:43:30Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25449247',
#   'pos': [41.1507225, -8.5845591],
#   'type': 'node'},
#  {'created': {'changeset': '497088',
#    'timestamp': '2009-04-13T21:19:05Z',
#    'uid': '104052',
#    'user': 'Nuno Gomes Lopes',
#    'version': '3'},
#   'id': '25449250',
#   'pos': [41.15413, -8.5840688],
#   'type': 'node'},
#  {'created': {'changeset': '8956209',
#    'timestamp': '2011-08-08T11:43:30Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25449251',
#   'pos': [41.1567511, -8.5832999],
#   'type': 'node'},
#  {'created': {'changeset': '8956209',
#    'timestamp': '2011-08-08T11:43:30Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25449255',
#   'pos': [41.163829, -8.580257],
#   'type': 'node'},
#  {'created': {'changeset': '8956209',
#    'timestamp': '2011-08-08T11:43:30Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25449257',
#   'pos': [41.1657318, -8.5783023],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:43:10Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25449258',
#   'pos': [41.1757128, -8.5668188],
#   'type': 'node'},
#  {'created': {'changeset': '7536648',
#    'timestamp': '2011-03-12T19:27:50Z',
#    'uid': '421038',
#    'user': 'Soraia',
#    'version': '4'},
#   'id': '25449261',
#   'pos': [41.1831167, -8.5583031],
#   'type': 'node'},
#  {'created': {'changeset': '7535765',
#    'timestamp': '2011-03-12T17:33:44Z',
#    'uid': '219492',
#    'user': 'EduRam',
#    'version': '4'},
#   'id': '25449262',
#   'pos': [41.1840308, -8.5575022],
#   'type': 'node'},
#  {'created': {'changeset': '7535765',
#    'timestamp': '2011-03-12T17:33:44Z',
#    'uid': '219492',
#    'user': 'EduRam',
#    'version': '4'},
#   'id': '25449263',
#   'pos': [41.185077, -8.5568476],
#   'type': 'node'},
#  {'created': {'changeset': '497088',
#    'timestamp': '2009-04-13T21:19:11Z',
#    'uid': '104052',
#    'user': 'Nuno Gomes Lopes',
#    'version': '3'},
#   'id': '25449264',
#   'pos': [41.186564, -8.5563026],
#   'type': 'node'},
#  {'created': {'changeset': '497088',
#    'timestamp': '2009-04-13T21:19:12Z',
#    'uid': '104052',
#    'user': 'Nuno Gomes Lopes',
#    'version': '3'},
#   'id': '25449265',
#   'pos': [41.1887762, -8.5555515],
#   'type': 'node'},
#  {'created': {'changeset': '497088',
#    'timestamp': '2009-04-13T21:19:12Z',
#    'uid': '104052',
#    'user': 'Nuno Gomes Lopes',
#    'version': '3'},
#   'id': '25449267',
#   'pos': [41.189519, -8.5553584],
#   'type': 'node'},
#  {'created': {'changeset': '497088',
#    'timestamp': '2009-04-13T21:19:13Z',
#    'uid': '104052',
#    'user': 'Nuno Gomes Lopes',
#    'version': '3'},
#   'id': '25449269',
#   'pos': [41.1903264, -8.5553155],
#   'type': 'node'},
#  {'created': {'changeset': '497088',
#    'timestamp': '2009-04-13T21:19:13Z',
#    'uid': '104052',
#    'user': 'Nuno Gomes Lopes',
#    'version': '3'},
#   'id': '25449271',
#   'pos': [41.1913922, -8.5553799],
#   'type': 'node'},
#  {'created': {'changeset': '29416281',
#    'timestamp': '2015-03-11T22:50:02Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '4'},
#   'id': '25449273',
#   'pos': [41.1976618, -8.5560299],
#   'type': 'node'},
#  {'created': {'changeset': '29416281',
#    'timestamp': '2015-03-11T22:50:02Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '4'},
#   'id': '25449279',
#   'pos': [41.1993144, -8.5562148],
#   'type': 'node'},
#  {'created': {'changeset': '29416281',
#    'timestamp': '2015-03-11T22:50:02Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '5'},
#   'id': '25449280',
#   'pos': [41.2001396, -8.5563647],
#   'type': 'node'},
#  {'created': {'changeset': '29416281',
#    'timestamp': '2015-03-11T22:50:02Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '5'},
#   'id': '25449281',
#   'pos': [41.2036967, -8.5572912],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:43:10Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25449282',
#   'pos': [41.2052824, -8.557547],
#   'type': 'node'},
#  {'created': {'changeset': '497088',
#    'timestamp': '2009-04-13T21:19:16Z',
#    'uid': '104052',
#    'user': 'Nuno Gomes Lopes',
#    'version': '3'},
#   'id': '25449283',
#   'pos': [41.2063589, -8.5574827],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:33Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449396',
#   'pos': [41.2132147, -8.5546699],
#   'type': 'node'},
#  {'created': {'changeset': '29416281',
#    'timestamp': '2015-03-11T22:50:02Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '5'},
#   'id': '25449585',
#   'pos': [41.2195738, -8.554183],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:33Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25449700',
#   'pos': [41.2203253, -8.5539061],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:33Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25449701',
#   'pos': [41.2211917, -8.5531227],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:34Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25449702',
#   'pos': [41.2216032, -8.5524392],
#   'type': 'node'},
#  {'created': {'changeset': '29416281',
#    'timestamp': '2015-03-11T22:50:02Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '4'},
#   'id': '25449703',
#   'pos': [41.2219027, -8.5516611],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:15Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25449704',
#   'pos': [41.2221189, -8.5506972],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:35Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25449705',
#   'pos': [41.2220445, -8.548168],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:35Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25449706',
#   'pos': [41.2219327, -8.5476293],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:15Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25449707',
#   'pos': [41.2212886, -8.5451606],
#   'type': 'node'},
#  {'created': {'changeset': '10741746',
#    'timestamp': '2012-02-20T19:48:59Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449709',
#   'pos': [41.2268405, -8.551996],
#   'type': 'node'},
#  {'created': {'changeset': '10741746',
#    'timestamp': '2012-02-20T19:48:59Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449710',
#   'pos': [41.2280687, -8.5517491],
#   'type': 'node'},
#  {'created': {'changeset': '10741746',
#    'timestamp': '2012-02-20T19:48:59Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449711',
#   'pos': [41.2294561, -8.5517563],
#   'type': 'node'},
#  {'created': {'changeset': '10741746',
#    'timestamp': '2012-02-20T19:48:59Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449716',
#   'pos': [41.2309419, -8.5520476],
#   'type': 'node'},
#  {'created': {'changeset': '10741746',
#    'timestamp': '2012-02-20T19:49:01Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449717',
#   'pos': [41.2315402, -8.5522579],
#   'type': 'node'},
#  {'created': {'changeset': '10741746',
#    'timestamp': '2012-02-20T19:49:01Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449718',
#   'pos': [41.2417676, -8.5560455],
#   'type': 'node'},
#  {'created': {'changeset': '10741746',
#    'timestamp': '2012-02-20T19:49:01Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449719',
#   'pos': [41.2431372, -8.556539],
#   'type': 'node'},
#  {'created': {'changeset': '10741746',
#    'timestamp': '2012-02-20T19:49:01Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449720',
#   'pos': [41.244754, -8.5569576],
#   'type': 'node'},
#  {'created': {'changeset': '10741746',
#    'timestamp': '2012-02-20T19:49:01Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25449723',
#   'pos': [41.2475612, -8.557283],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449731',
#   'pos': [41.2677911, -8.5588668],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449732',
#   'pos': [41.2706081, -8.5593358],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449733',
#   'pos': [41.2712272, -8.5594084],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449734',
#   'pos': [41.2725712, -8.5592878],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449735',
#   'pos': [41.2739217, -8.558717],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449736',
#   'pos': [41.2745176, -8.5582989],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449737',
#   'pos': [41.2751076, -8.5577578],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449738',
#   'pos': [41.2759473, -8.5566915],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449739',
#   'pos': [41.2787003, -8.5525138],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449740',
#   'pos': [41.2792942, -8.551915],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449744',
#   'pos': [41.2798266, -8.5514795],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449745',
#   'pos': [41.2804654, -8.5510566],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449746',
#   'pos': [41.282114, -8.5502308],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449747',
#   'pos': [41.2828797, -8.549776],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449748',
#   'pos': [41.2835505, -8.5493332],
#   'railway': 'switch',
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449749',
#   'pos': [41.2853462, -8.5477983],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449750',
#   'pos': [41.2865459, -8.5469939],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449751',
#   'pos': [41.2878914, -8.5465237],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449752',
#   'pos': [41.2903821, -8.5462822],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449763',
#   'pos': [41.2945763, -8.5460022],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449764',
#   'pos': [41.2955003, -8.5461261],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449765',
#   'pos': [41.2962367, -8.5463234],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449766',
#   'pos': [41.2973304, -8.5467955],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:41Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449767',
#   'pos': [41.3028583, -8.5497549],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449812',
#   'pos': [41.3034896, -8.5499739],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449813',
#   'pos': [41.304541, -8.5501777],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449814',
#   'pos': [41.3079159, -8.5504892],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449815',
#   'pos': [41.3084384, -8.5505767],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25449816',
#   'pos': [41.3096158, -8.5509398],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '10'},
#   'id': '25449817',
#   'pos': [41.3124807, -8.5524987],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '10'},
#   'id': '25449821',
#   'pos': [41.312981, -8.5527424],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '10'},
#   'id': '25449822',
#   'pos': [41.313572, -8.5529911],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '10'},
#   'id': '25449823',
#   'pos': [41.3141717, -8.5531904],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '10'},
#   'id': '25449824',
#   'pos': [41.3158005, -8.5536011],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '10'},
#   'id': '25449825',
#   'pos': [41.3162823, -8.5536965],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '8'},
#   'id': '25449826',
#   'pos': [41.3243654, -8.5568634],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25449827',
#   'pos': [41.3287496, -8.5587815],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25449828',
#   'pos': [41.3292524, -8.5590089],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25449829',
#   'pos': [41.3310696, -8.559378],
#   'type': 'node'},
#  {'created': {'changeset': '25821699',
#    'timestamp': '2014-10-02T23:35:33Z',
#    'uid': '2316417',
#    'user': u'S\xe9rgio Ab\xedlio',
#    'version': '9'},
#   'id': '25449990',
#   'pos': [41.3336418, -8.5593579],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25449993',
#   'pos': [41.3345969, -8.5591499],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25449994',
#   'pos': [41.3349867, -8.5589957],
#   'type': 'node'},
#  {'created': {'changeset': '25821699',
#    'timestamp': '2014-10-02T23:35:33Z',
#    'uid': '2316417',
#    'user': u'S\xe9rgio Ab\xedlio',
#    'version': '8'},
#   'id': '25449995',
#   'pos': [41.3356542, -8.5585357],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25449996',
#   'pos': [41.3362511, -8.5580131],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25449997',
#   'pos': [41.3388775, -8.5550354],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25449999',
#   'pos': [41.3406388, -8.5525074],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25450068',
#   'pos': [41.3419034, -8.5498041],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '8'},
#   'id': '25450074',
#   'pos': [41.3424208, -8.5486291],
#   'type': 'node'},
#  {'created': {'changeset': '12190809',
#    'timestamp': '2012-07-11T22:00:14Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '9'},
#   'id': '25450081',
#   'pos': [41.342769, -8.5479158],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25450094',
#   'pos': [41.3449216, -8.5440532],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25450115',
#   'pos': [41.3490194, -8.53481],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25450132',
#   'pos': [41.3493219, -8.5340439],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25450135',
#   'pos': [41.3495524, -8.5333068],
#   'type': 'node'},
#  {'created': {'changeset': '35758756',
#    'timestamp': '2015-12-04T22:45:42Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '9'},
#   'id': '25450138',
#   'pos': [41.3496945, -8.5326882],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '8'},
#   'id': '25450442',
#   'pos': [41.3878592, -8.5262574],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450443',
#   'pos': [41.3908302, -8.5261339],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450444',
#   'pos': [41.3914973, -8.5262399],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450447',
#   'pos': [41.3923045, -8.5265532],
#   'type': 'node'},
#  {'created': {'changeset': '8769530',
#    'timestamp': '2011-07-19T15:34:23Z',
#    'uid': '426108',
#    'user': 'catiasalgado',
#    'version': '8'},
#   'id': '25450448',
#   'pos': [41.3930771, -8.5270566],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450449',
#   'pos': [41.3937536, -8.5277227],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450450',
#   'pos': [41.3942629, -8.5284007],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '8'},
#   'id': '25450452',
#   'pos': [41.3956787, -8.530343],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450453',
#   'pos': [41.3961072, -8.5307353],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450454',
#   'pos': [41.396618, -8.531089],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450455',
#   'pos': [41.3972927, -8.5314092],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450456',
#   'pos': [41.3981184, -8.5316043],
#   'type': 'node'},
#  {'created': {'changeset': '21030701',
#    'timestamp': '2014-03-10T17:44:12Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '25450457',
#   'pos': [41.3988526, -8.5316132],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:35Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25452376',
#   'pos': [41.2209438, -8.5433278],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:35Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25452377',
#   'pos': [41.2209178, -8.5425446],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:35Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25452378',
#   'pos': [41.2209943, -8.5408249],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:35Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25452379',
#   'pos': [41.2210742, -8.5391897],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:35Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25452380',
#   'pos': [41.2208559, -8.536941],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:35Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25452381',
#   'pos': [41.220668, -8.5360832],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:36Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25452382',
#   'pos': [41.2199658, -8.5337135],
#   'type': 'node'},
#  {'created': {'changeset': '10755265',
#    'timestamp': '2012-02-22T00:24:36Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '3'},
#   'id': '25452383',
#   'pos': [41.2197018, -8.5331105],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25452384',
#   'pos': [41.2188646, -8.5318253],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25452385',
#   'pos': [41.2176321, -8.5308571],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25452386',
#   'pos': [41.2164152, -8.5299423],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25452387',
#   'pos': [41.2159155, -8.5293549],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25452388',
#   'pos': [41.2151587, -8.5281637],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:31:25Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452389',
#   'pos': [41.2142581, -8.5265682],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:31:25Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452390',
#   'pos': [41.2125331, -8.5233626],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '2'},
#   'id': '25452391',
#   'pos': [41.2114521, -8.5215718],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452394',
#   'pos': [41.2050914, -8.5115383],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452395',
#   'pos': [41.2047101, -8.5109721],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452396',
#   'pos': [41.2035413, -8.5097043],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452397',
#   'pos': [41.2008493, -8.5076384],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:31:25Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452398',
#   'pos': [41.2070053, -8.5147096],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452399',
#   'pos': [41.1993799, -8.5064758],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452400',
#   'pos': [41.1988682, -8.5059856],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452401',
#   'pos': [41.1980463, -8.5047981],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452402',
#   'pos': [41.1977132, -8.5040449],
#   'type': 'node'},
#  {'created': {'changeset': '695048',
#    'timestamp': '2008-12-31T22:21:46Z',
#    'uid': '84681',
#    'user': 'SK53',
#    'version': '2'},
#   'id': '25452403',
#   'pos': [41.1974163, -8.5030661],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:22:13Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452404',
#   'pos': [41.1965975, -8.4998852],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452405',
#   'pos': [41.1963673, -8.4991654],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:16Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452406',
#   'pos': [41.1956707, -8.4976616],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:22:13Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452407',
#   'pos': [41.1937211, -8.4945122],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452408',
#   'pos': [41.1907942, -8.489815],
#   'type': 'node'},
#  {'created': {'changeset': '695048',
#    'timestamp': '2008-12-31T22:21:46Z',
#    'uid': '84681',
#    'user': 'SK53',
#    'version': '2'},
#   'id': '25452409',
#   'pos': [41.1903441, -8.4892473],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452410',
#   'pos': [41.1890948, -8.4880564],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452411',
#   'pos': [41.1849677, -8.4846349],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452412',
#   'pos': [41.1844808, -8.4842226],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452413',
#   'pos': [41.1837756, -8.4834618],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452414',
#   'pos': [41.1829003, -8.4821632],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452415',
#   'pos': [41.1822056, -8.4806896],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452416',
#   'pos': [41.1817184, -8.4797761],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452417',
#   'pos': [41.1811339, -8.479097],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452418',
#   'pos': [41.1806439, -8.4786302],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452419',
#   'pos': [41.1795285, -8.4779876],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452420',
#   'pos': [41.1754756, -8.4765852],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452421',
#   'pos': [41.1748733, -8.4762596],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452422',
#   'pos': [41.1739102, -8.4754145],
#   'type': 'node'},
#  {'created': {'changeset': '35605433',
#    'timestamp': '2015-11-27T06:51:35Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '5'},
#   'id': '25452423',
#   'pos': [41.1730085, -8.4740365],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452424',
#   'pos': [41.1725052, -8.4729526],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452425',
#   'pos': [41.171762, -8.4709817],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452426',
#   'pos': [41.1714598, -8.4701933],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452427',
#   'pos': [41.1711244, -8.4695257],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452428',
#   'pos': [41.170342, -8.4684202],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452429',
#   'pos': [41.1653109, -8.4625344],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452430',
#   'pos': [41.1644147, -8.4614722],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:04:47Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452431',
#   'pos': [41.1637401, -8.4604908],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:17Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452432',
#   'pos': [41.1617997, -8.4572985],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452434',
#   'pos': [41.1612486, -8.4564081],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452435',
#   'pos': [41.1607558, -8.4554905],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:04:47Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452436',
#   'pos': [41.1603925, -8.4545809],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452437',
#   'pos': [41.1600115, -8.4530648],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:04:47Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452438',
#   'pos': [41.1598959, -8.4522183],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452439',
#   'pos': [41.1598447, -8.4514175],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:04:47Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452440',
#   'pos': [41.1599255, -8.4498647],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452441',
#   'pos': [41.1602025, -8.4484265],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452442',
#   'pos': [41.1605013, -8.4474878],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452443',
#   'pos': [41.1611011, -8.446189],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452444',
#   'pos': [41.1615846, -8.44545],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452445',
#   'pos': [41.1626504, -8.4439268],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452446',
#   'pos': [41.1630514, -8.4432769],
#   'type': 'node'},
#  {'created': {'changeset': '8915703',
#    'timestamp': '2011-08-04T00:27:46Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452447',
#   'pos': [41.1635744, -8.4420559],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452448',
#   'pos': [41.1637625, -8.4412286],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452449',
#   'pos': [41.163894, -8.4395962],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452450',
#   'pos': [41.163605, -8.435302],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452451',
#   'pos': [41.1633789, -8.4334088],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:18Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452452',
#   'pos': [41.1630802, -8.4321312],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452488',
#   'pos': [41.1620571, -8.4278476],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452498',
#   'pos': [41.1617309, -8.4264236],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452499',
#   'pos': [41.161557, -8.4254407],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452500',
#   'pos': [41.161401, -8.4233985],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452501',
#   'pos': [41.1611317, -8.4134348],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452502',
#   'pos': [41.1610857, -8.4126128],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452503',
#   'pos': [41.160748, -8.4110245],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452504',
#   'pos': [41.1603964, -8.4101693],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452505',
#   'pos': [41.1596838, -8.4090563],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452506',
#   'pos': [41.1587251, -8.4079868],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452507',
#   'pos': [41.1577596, -8.4069256],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452508',
#   'pos': [41.1572218, -8.4061793],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:04:47Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452509',
#   'pos': [41.156642, -8.4051754],
#   'type': 'node'},
#  {'created': {'changeset': '14266530',
#    'timestamp': '2012-12-14T01:48:18Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '4'},
#   'id': '25452541',
#   'pos': [41.1521464, -8.3955682],
#   'type': 'node'},
#  {'created': {'changeset': '14266530',
#    'timestamp': '2012-12-14T01:48:19Z',
#    'uid': '602999',
#    'user': 'rtafav2',
#    'version': '5'},
#   'id': '25452543',
#   'pos': [41.1514983, -8.3941707],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452544',
#   'pos': [41.1509499, -8.3923415],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452545',
#   'pos': [41.1508476, -8.3909172],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:19Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452546',
#   'pos': [41.1508782, -8.3899543],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:20Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452551',
#   'pos': [41.1509627, -8.3892993],
#   'type': 'node'},
#  {'created': {'changeset': '8915703',
#    'timestamp': '2011-08-04T00:27:47Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452553',
#   'pos': [41.1514056, -8.3877726],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:20Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452554',
#   'pos': [41.1521508, -8.3864068],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:20Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452555',
#   'pos': [41.1526314, -8.3858102],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:20Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452556',
#   'pos': [41.1538207, -8.3849038],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:04:47Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452557',
#   'pos': [41.154686, -8.384428],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:04:47Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '5'},
#   'id': '25452577',
#   'pos': [41.1558937, -8.3834188],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:20Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '3'},
#   'id': '25452581',
#   'pos': [41.1567723, -8.3820851],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T12:55:20Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '4'},
#   'id': '25452587',
#   'pos': [41.1596873, -8.3762509],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
#    'timestamp': '2011-08-04T14:04:47Z',
#    'uid': '499804',
#    'user': 'rtafav',
#    'version': '5'},
#   'id': '25452591',
#   'pos': [41.1598851, -8.3756238],
#   'type': 'node'},
#  {'created': {'changeset': '8919415',
# ...
#    'user': 'TaedeT',
#    'version': '2'},
#   'id': '26017005',
#   'pos': [41.0915505, -8.5874684],
#   'type': 'node'},
#  {'created': {'changeset': '8407055',
#    'timestamp': '2011-06-11T16:03:18Z',
#    'uid': '57577',
#    'user': 'TaedeT',
#    'version': '2'},
#   'id': '26017006',
#   'pos': [41.0906612, -8.5871183],
#   'type': 'node'},
#  {'created': {'changeset': '219708',
#    'timestamp': '2007-02-19T13:25:25Z',
#    'uid': '5404',
#    'user': 'jmorais',
#    'version': '1'},
#   'id': '26017007',
#   'pos': [41.0906524, -8.5869507],
#   'type': 'node'},
#  {'created': {'changeset': '36413017',
#    'timestamp': '2016-01-06T20:41:29Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '3'},
#   'id': '26017008',
#   'pos': [41.0864571, -8.5851312],
#   'type': 'node'},
#  {'created': {'changeset': '36413017',
#    'timestamp': '2016-01-06T20:41:29Z',
#    'uid': '2678365',
#    'user': 'zermes',
#    'version': '2'},
#   'id': '26017009',
#   'pos': [41.0865086, -8.5849685],
#   'type': 'node'},
#  {'created': {'changeset': '219708',
#    'timestamp': '2007-02-19T13:25:25Z',
#    'uid': '5404',
#    'user': 'jmorais',
#    'version': '1'},
#   'id': '26017011',
#   'pos': [41.0827769, -8.583194],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26057762',
#   'pos': [41.1809886, -8.5940472],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '4'},
#   'id': '26057764',
#   'pos': [41.1809322, -8.5942248],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26057767',
#   'pos': [41.1807003, -8.5944816],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26057769',
#   'pos': [41.1804004, -8.5944996],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26057772',
#   'pos': [41.1801249, -8.5942096],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26057774',
#   'pos': [41.1800663, -8.593808],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '4'},
#   'id': '26057776',
#   'pos': [41.1801854, -8.5934755],
#   'type': 'node'},
#  {'created': {'changeset': '33585356',
#    'timestamp': '2015-08-25T23:30:54Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057801',
#   'pos': [41.1820933, -8.593662],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057803',
#   'pos': [41.1817993, -8.5937201],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26057804',
#   'pos': [41.1816706, -8.5938353],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057805',
#   'pos': [41.1815217, -8.5943518],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '5'},
#   'id': '26057813',
#   'pos': [41.1815228, -8.5945082],
#   'type': 'node'},
#  {'created': {'changeset': '26205509',
#    'timestamp': '2014-10-20T04:02:03Z',
#    'uid': '2316417',
#    'user': u'S\xe9rgio Ab\xedlio',
#    'version': '3'},
#   'id': '26057846',
#   'pos': [41.1800119, -8.5904757],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057847',
#   'pos': [41.1804752, -8.5916519],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057848',
#   'pos': [41.1805559, -8.5917689],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26057849',
#   'pos': [41.1808454, -8.5920946],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26057850',
#   'pos': [41.1812399, -8.5923691],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057852',
#   'pos': [41.1821946, -8.592838],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '9'},
#   'id': '26057853',
#   'pos': [41.180349, -8.5920399],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '4'},
#   'id': '26057854',
#   'pos': [41.1801681, -8.5918091],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057855',
#   'pos': [41.179677, -8.5917379],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057856',
#   'pos': [41.1794347, -8.5920816],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057857',
#   'pos': [41.1794797, -8.5926422],
#   'type': 'node'},
#  {'created': {'changeset': '33578120',
#    'timestamp': '2015-08-25T17:49:24Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26057858',
#   'pos': [41.179758, -8.592906],
#   'type': 'node'},
#  {'barrier': 'toll_booth',
#   'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '8'},
#   'id': '26058104',
#   'pos': [41.2449614, -8.5655067],
#   'type': 'node'},
#  {'created': {'changeset': '25822948',
#    'timestamp': '2014-10-03T02:16:13Z',
#    'uid': '2316417',
#    'user': u'S\xe9rgio Ab\xedlio',
#    'version': '5'},
#   'id': '26058105',
#   'pos': [41.2454809, -8.5657861],
#   'type': 'node'},
#  {'barrier': 'toll_booth',
#   'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '5'},
#   'id': '26058110',
#   'payment:via_verde': 'yes',
#   'pos': [41.2449127, -8.5656693],
#   'type': 'node'},
#  {'created': {'changeset': '7642459',
#    'timestamp': '2011-03-22T23:09:48Z',
#    'uid': '364739',
#    'user': 'j123b567',
#    'version': '2'},
#   'id': '26058112',
#   'pos': [41.2456433, -8.5660543],
#   'type': 'node'},
#  {'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '6'},
#   'id': '26058120',
#   'pos': [41.2464596, -8.5663145],
#   'type': 'node'},
#  {'created': {'changeset': '240999',
#    'timestamp': '2007-03-20T22:49:21Z',
#    'uid': '5404',
#    'user': 'jmorais',
#    'version': '1'},
#   'id': '26058125',
#   'pos': [41.2464686, -8.5665705],
#   'type': 'node'},
#  {'created': {'changeset': '431536',
#    'timestamp': '2008-05-12T19:48:48Z',
#    'uid': '15885',
#    'user': 'Eloi  Ribeiro',
#    'version': '2'},
#   'id': '26121319',
#   'pos': [41.2404396, -8.5644542],
#   'type': 'node'},
#  {'created': {'changeset': '7642459',
#    'timestamp': '2011-03-22T23:07:48Z',
#    'uid': '364739',
#    'user': 'j123b567',
#    'version': '2'},
#   'id': '26121320',
#   'pos': [41.2401294, -8.5645023],
#   'type': 'node'},
#  {'created': {'changeset': '7642459',
#    'timestamp': '2011-03-22T23:09:08Z',
#    'uid': '364739',
#    'user': 'j123b567',
#    'version': '2'},
#   'id': '26121321',
#   'pos': [41.2399797, -8.564584],
#   'type': 'node'},
#  {'created': {'changeset': '7642459',
#    'timestamp': '2011-03-22T23:09:47Z',
#    'uid': '364739',
#    'user': 'j123b567',
#    'version': '2'},
#   'id': '26121322',
#   'pos': [41.2398486, -8.5647561],
#   'type': 'node'},
#  {'created': {'changeset': '7642459',
#    'timestamp': '2011-03-22T23:08:53Z',
#    'uid': '364739',
#    'user': 'j123b567',
#    'version': '2'},
#   'id': '26121323',
#   'pos': [41.2397703, -8.564928],
#   'type': 'node'},
#  {'created': {'changeset': '25822948',
#    'timestamp': '2014-10-03T02:16:12Z',
#    'uid': '2316417',
#    'user': u'S\xe9rgio Ab\xedlio',
#    'version': '3'},
#   'id': '26121324',
#   'pos': [41.2397252, -8.5651661],
#   'type': 'node'},
#  {'created': {'changeset': '25822948',
#    'timestamp': '2014-10-03T02:16:12Z',
#    'uid': '2316417',
#    'user': u'S\xe9rgio Ab\xedlio',
#    'version': '3'},
#   'id': '26121325',
#   'pos': [41.2396482, -8.5663585],
#   'type': 'node'},
#  {'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '4'},
#   'id': '26121327',
#   'pos': [41.2422205, -8.5648577],
#   'type': 'node'},
#  {'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121328',
#   'pos': [41.2421077, -8.5648762],
#   'type': 'node'},
#  {'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121329',
#   'pos': [41.2419995, -8.5649056],
#   'type': 'node'},
#  {'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121330',
#   'pos': [41.2417004, -8.5650579],
#   'type': 'node'},
#  {'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121331',
#   'pos': [41.2414727, -8.5652585],
#   'type': 'node'},
#  {'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121332',
#   'pos': [41.2411932, -8.5656495],
#   'type': 'node'},
#  {'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '4'},
#   'id': '26121333',
#   'pos': [41.2410632, -8.5659605],
#   'type': 'node'},
#  {'created': {'changeset': '7642459',
#    'timestamp': '2011-03-22T23:09:08Z',
#    'uid': '364739',
#    'user': 'j123b567',
#    'version': '3'},
#   'id': '26121335',
#   'pos': [41.2429673, -8.5643427],
#   'type': 'node'},
#  {'created': {'changeset': '33595964',
#    'timestamp': '2015-08-26T13:16:42Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26121336',
#   'pos': [41.2425202, -8.5641783],
#   'type': 'node'},
#  {'created': {'changeset': '223231',
#    'timestamp': '2007-02-24T12:01:13Z',
#    'uid': '5404',
#    'user': 'jmorais',
#    'version': '1'},
#   'id': '26121337',
#   'pos': [41.242089, -8.5640488],
#   'type': 'node'},
#  {'created': {'changeset': '223231',
#    'timestamp': '2007-02-24T12:01:15Z',
#    'uid': '5404',
#    'user': 'jmorais',
#    'version': '1'},
#   'id': '26121338',
#   'pos': [41.2417179, -8.56392],
#   'type': 'node'},
#  {'created': {'changeset': '223231',
#    'timestamp': '2007-02-24T12:01:18Z',
#    'uid': '5404',
#    'user': 'jmorais',
#    'version': '1'},
#   'id': '26121339',
#   'pos': [41.2414598, -8.5637484],
#   'type': 'node'},
#  {'created': {'changeset': '223231',
#    'timestamp': '2007-02-24T12:01:19Z',
#    'uid': '5404',
#    'user': 'jmorais',
#    'version': '1'},
#   'id': '26121340',
#   'pos': [41.2412984, -8.5634909],
#   'type': 'node'},
#  {'created': {'changeset': '223231',
#    'timestamp': '2007-02-24T12:01:21Z',
#    'uid': '5404',
#    'user': 'jmorais',
#    'version': '1'},
#   'id': '26121343',
#   'pos': [41.2411694, -8.5631475],
#   'type': 'node'},
#  {'created': {'changeset': '35968974',
#    'timestamp': '2015-12-15T15:49:14Z',
#    'uid': '1131231',
#    'user': 'Barrocas',
#    'version': '4'},
#   'highway': 'motorway_junction',
#   'id': '26121640',
#   'name': u'A7 Guimar\xe3es, Vila do Conde, Famalic\xe3o',
#   'pos': [41.3722882, -8.5032064],
#   'ref': '6',
#   'type': 'node'},
#  {'created': {'changeset': '34591804',
#    'timestamp': '2015-10-12T14:37:02Z',
#    'uid': '1131231',
#    'user': 'Barrocas',
#    'version': '4'},
#   'id': '26121641',
#   'pos': [41.3727245, -8.5029676],
#   'type': 'node'},
#  {'created': {'changeset': '34591804',
#    'timestamp': '2015-10-12T14:37:02Z',
#    'uid': '1131231',
#    'user': 'Barrocas',
#    'version': '4'},
#   'id': '26121642',
#   'pos': [41.3732286, -8.5022096],
#   'type': 'node'},
#  {'created': {'changeset': '34591804',
#    'timestamp': '2015-10-12T14:37:02Z',
#    'uid': '1131231',
#    'user': 'Barrocas',
#    'version': '4'},
#   'id': '26121643',
#   'pos': [41.3733571, -8.5018361],
#   'type': 'node'},
#  {'created': {'changeset': '31387466',
#    'timestamp': '2015-05-23T01:00:14Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121644',
#   'pos': [41.3735721, -8.5015461],
#   'type': 'node'},
#  {'created': {'changeset': '31387466',
#    'timestamp': '2015-05-23T01:00:14Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121645',
#   'pos': [41.3739042, -8.5015166],
#   'type': 'node'},
#  {'created': {'changeset': '31387466',
#    'timestamp': '2015-05-23T01:00:14Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26121646',
#   'pos': [41.3741645, -8.5017722],
#   'type': 'node'},
#  {'created': {'changeset': '31387466',
#    'timestamp': '2015-05-23T01:00:15Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121647',
#   'pos': [41.3747387, -8.5028071],
#   'type': 'node'},
#  {'created': {'changeset': '31387466',
#    'timestamp': '2015-05-23T01:00:15Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121648',
#   'pos': [41.3750704, -8.5031575],
#   'type': 'node'},
#  {'created': {'changeset': '31387466',
#    'timestamp': '2015-05-23T01:00:15Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121649',
#   'pos': [41.3754109, -8.5032238],
#   'type': 'node'},
#  {'created': {'changeset': '31398995',
#    'timestamp': '2015-05-23T14:31:46Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121650',
#   'pos': [41.3771204, -8.5023094],
#   'type': 'node'},
#  {'created': {'changeset': '34591869',
#    'timestamp': '2015-10-12T14:40:47Z',
#    'uid': '1131231',
#    'user': 'Barrocas',
#    'version': '6'},
#   'id': '26121654',
#   'pos': [41.3760933, -8.502992],
#   'type': 'node'},
#  {'created': {'changeset': '31398995',
#    'timestamp': '2015-05-23T14:31:46Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121659',
#   'pos': [41.3746883, -8.5028384],
#   'type': 'node'},
#  {'created': {'changeset': '31398995',
#    'timestamp': '2015-05-23T14:31:46Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '3'},
#   'id': '26121661',
#   'pos': [41.3752409, -8.5032991],
#   'type': 'node'},
#  {'created': {'changeset': '31387466',
#    'timestamp': '2015-05-23T01:00:14Z',
#    'uid': '1963239',
#    'user': 'ViriatoLusitano',
#    'version': '2'},
#   'id': '26121664',
#   'pos': [41.3740587, -8.5017335],
#   'type': 'node'},
#  ...]
